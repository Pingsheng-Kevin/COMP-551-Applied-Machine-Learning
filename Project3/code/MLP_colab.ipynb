# %%
import tensorflow as tf

import numpy as np

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# print(x_train[0])
train_dist = np.bincount(y_train)
labels = [i for i in range(10)]
# test_dist = np.bincount(y_test)*100.0/np.sum(y_test) almost the same with training
# print(x_train.shape)
# print(y_train[0])     5
fig1, ax1 = plt.subplots()
plt.title('Class Distribution of MNIST')
patches, texts, autotexts = ax1.pie(train_dist, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
[_.set_fontsize(8) for _ in texts]
plt.show()
plt.clf()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
plt.imshow(x_train[0])
plt.colorbar()
# plt.clf()

# %%
plt.clf()

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1]*x_train.shape[2]))

# %%
X_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1]*x_test.shape[2]))

# %%
X_train, X_test = X_train/255.0, X_test/255.0 # normalize image

from MLP import MLPClassifier

# %%
# print(X_train.shape) (60000, 784)

clf = MLPClassifier(hidden_layer_sizes=(), alpha=0, max_iter=400)
acc_list_1 = []
acc_list_1_train = []
for epoch in range(20):
    clf.fit(X_train, y_train)
    acc_list_1.append(clf.score(X_test, y_test)*100.0)
    acc_list_1_train.append(clf.score(X_train, y_train)*100.0)
print(f'The highest score of this model(no hidden layer & No L2) is: {np.max(acc_list_1)}%, No.{np.argmax(acc_list_1)+1} epoch')
plt.plot([i+1 for i in range(20)], acc_list_1, marker='o', color='blue', label='testing accuracy')
plt.plot([i+1 for i in range(20)], acc_list_1_train, marker='*', color='red', label='training accuracy')
plt.xlabel('Training epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Training epochs (No hidden layer MLP)')
plt.show()
print(acc_list_1)
print(acc_list_1_train)
# Out:
# The highest score of this model(no hidden layer & No L2) is: 92.80000000000001%, No.11 epoch
# [92.65, 92.56, 92.61, 92.47, 92.62, 92.51, 92.7, 92.71000000000001, 92.60000000000001, 92.53, 92.80000000000001, 92.58999999999999, 92.65, 92.57, 92.67, 92.60000000000001, 92.53, 92.62, 92.60000000000001, 92.62]
# [94.185, 94.11166666666666, 94.04166666666667, 94.09333333333333, 94.13166666666667, 94.12833333333333, 94.15333333333334, 94.04666666666667, 94.17166666666667, 94.185, 94.06833333333333, 94.21000000000001, 94.10666666666667, 94.12833333333333, 94.14833333333334, 94.135, 94.105, 94.18166666666666, 94.16333333333333, 94.05166666666666]

# %%
acc_list_1 = [92.65, 92.56, 92.61, 92.47, 92.62, 92.51, 92.7, 92.71000000000001, 92.60000000000001, 92.53, 92.80000000000001, 92.58999999999999, 92.65, 92.57, 92.67, 92.60000000000001, 92.53, 92.62, 92.60000000000001, 92.62]
acc_list_1_train = [94.185, 94.11166666666666, 94.04166666666667, 94.09333333333333, 94.13166666666667, 94.12833333333333, 94.15333333333334, 94.04666666666667, 94.17166666666667, 94.185, 94.06833333333333, 94.21000000000001, 94.10666666666667, 94.12833333333333, 94.14833333333334, 94.135, 94.105, 94.18166666666666, 94.16333333333333, 94.05166666666666]

# %%
plt.clf()

# %%
clf = MLPClassifier(hidden_layer_sizes=(128, 1), alpha=0, max_iter=200)
acc_list_2 = []
acc_list_2_train = []
for epoch in range(10):
    clf.fit(X_train, y_train)
    acc_list_2.append(clf.score(X_test, y_test)*100.0)
    acc_list_2_train.append(clf.score(X_train, y_train)*100.0)
print(f'The highest score of this model(1 hidden layer & No L2) is: {np.max(acc_list_2)}%, No.{np.argmax(acc_list_2)+1} epoch')
plt.plot([i+1 for i in range(10)], acc_list_2, marker='o', color='blue', label='testing accuracy')
plt.plot([i+1 for i in range(10)], acc_list_2_train, marker='*', color='red', label='training accuracy')
plt.xlabel('Training epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Training epochs (1 hidden layer MLP)')
plt.legend()
plt.show()
print(acc_list_2)
print(acc_list_2_train)
# Out:
# The highest score of this model(1 hidden layer & No L2) is: 65.16999999999999%, No.5 epoch
# [56.06, 47.65, 64.53999999999999, 57.57, 65.16999999999999, 48.38, 54.6, 11.35, 54.56999999999999, 55.720000000000006]
# [58.44666666666667, 49.92333333333333, 69.07666666666667, 59.30166666666666, 69.38833333333334, 50.544999999999995, 59.09833333333333, 11.236666666666666, 58.68666666666667, 58.9]

# %%
acc_list_2 = [56.06, 47.65, 64.53999999999999, 57.57, 65.16999999999999, 48.38, 54.6, 11.35, 54.56999999999999, 55.720000000000006]
acc_list_2_train = [58.44666666666667, 49.92333333333333, 69.07666666666667, 59.30166666666666, 69.38833333333334, 50.544999999999995, 59.09833333333333, 11.236666666666666, 58.68666666666667, 58.9]

# %%
plt.clf()

# %%
clf = MLPClassifier(hidden_layer_sizes=(128, 2), alpha=0, max_iter=200)
acc_list_3 = []
acc_list_3_train = []
for epoch in range(10):
    clf.fit(X_train, y_train)
    acc_list_3.append(clf.score(X_test, y_test)*100.0)
    acc_list_3_train.append(clf.score(X_train, y_train)*100.0)
print(f'The highest score of this model(2 hidden layer & No L2) is: {np.max(acc_list_3)}%, No.{np.argmax(acc_list_3)+1} epoch')
plt.plot([i+1 for i in range(10)], acc_list_3, marker='o', color='blue', label='testing accuracy')
plt.plot([i+1 for i in range(10)], acc_list_3_train, marker='*', color='red', label='training accuracy')
plt.xlabel('Training epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Training epochs (2 hidden layers MLP)')
plt.legend()
plt.show()
print(acc_list_3)
print(acc_list_3_train)
# Out:
# The highest score of this model(2 hidden layer & No L2) is: 93.91000000000001%, No.9 epoch
# [92.57, 84.52, 92.80000000000001, 92.75, 93.21000000000001, 92.24, 84.11, 92.43, 93.91000000000001, 93.45]
# [99.51833333333333, 90.29833333333333, 99.75833333333334, 99.63833333333334, 99.64333333333333, 99.38166666666667, 89.77333333333334, 99.45666666666668, 99.64166666666667, 99.63499999999999]

# %%
acc_list_3 = [92.57, 84.52, 92.80000000000001, 92.75, 93.21000000000001, 92.24, 84.11, 92.43, 93.91000000000001, 93.45]
acc_list_3_train = [99.51833333333333, 90.29833333333333, 99.75833333333334, 99.63833333333334, 99.64333333333333, 99.38166666666667, 89.77333333333334, 99.45666666666668, 99.64166666666667, 99.63499999999999]

# %%
plt.clf()

# %%
plt.plot([i+1 for i in range(10)], acc_list_1[:10], marker='o', color='blue', label='No hidden layer(testing)')
plt.plot([i+1 for i in range(10)], acc_list_2, marker='*', color='red', label='1 hidden layer(testing)')
plt.plot([i+1 for i in range(10)], acc_list_3, marker='.', color='green', label='2 hidden layers(testing)')
plt.plot([i+1 for i in range(10)], acc_list_1_train[:10], marker='o', color='blue', label='No hidden layer(training)', linestyle='dashed')
plt.plot([i+1 for i in range(10)], acc_list_2_train, marker='*', color='red', label='1 hidden layer(training)', linestyle='dashed')
plt.plot([i+1 for i in range(10)], acc_list_3_train, marker='.', color='green', label='2 hidden layers(training)', linestyle='dashed')
plt.xlabel('Training epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Training epochs')
plt.legend()
plt.show()

# %%
plt.clf()

# %%
clf_tanh = MLPClassifier(hidden_layer_sizes=(128, 2), alpha=0, activation="tanh", max_iter=400)
clf_sig = MLPClassifier(hidden_layer_sizes=(128, 2), alpha=0, activation="logistic", max_iter=400)
acc_list_tanh = []
acc_list_sig = []
acc_list_tanh_train = []
acc_list_sig_train = []
for epoch in range(10):
    clf_tanh.fit(X_train, y_train)
    clf_sig.fit(X_train, y_train)
    acc_list_tanh.append(clf_tanh.score(X_test, y_test)*100.0)
    acc_list_sig.append(clf_sig.score(X_test, y_test)*100.0)
    acc_list_tanh_train.append(clf_tanh.score(X_train, y_train)*100.0)
    acc_list_sig_train.append(clf_sig.score(X_train, y_train)*100.0)
plt.plot([i+1 for i in range(10)], acc_list_tanh, marker='o', color='green', label='tanh testing accuracy')
plt.plot([i+1 for i in range(10)], acc_list_sig, marker='*', color='orange', label='sigmoid testing accuracy')
plt.plot([i+1 for i in range(10)], acc_list_3, marker='x', color='purple', label='ReLU testing accuracy')
plt.xlabel('Training epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Training epochs (2 hidden layers MLP with different activation functions)')
plt.legend()
plt.show()
print(f'The highest score of the model(using tanh) is: {np.max(acc_list_tanh)}%, No. {np.argmax(acc_list_tanh)+1} epoch.')
print(f'The highest score of the model(using sigmoid) is: {np.max(acc_list_sig)}%, No. {np.argmax(acc_list_sig)+1} epoch.')
print(acc_list_tanh)
print(acc_list_tanh_train)
print(acc_list_sig)
print(acc_list_sig_train)
# Out:
# The highest score of the model(using tanh) is: 94.25%, No. 2 epoch.
# The highest score of the model(using sigmoid) is: 92.81%, No. 4 epoch.
# [93.36, 94.25, 92.03, 93.57, 93.57, 92.54, 93.5, 94.08, 94.25, 93.82000000000001]
# [99.99, 99.99166666666667, 99.995, 99.995, 99.99166666666667, 99.97500000000001, 99.98, 99.965, 99.99833333333333, 99.995]
# [91.63, 92.67, 92.78, 92.81, 92.42, 92.77, 91.43, 91.42, 92.36999999999999, 92.51]
# [99.97166666666666, 99.97333333333333, 99.96166666666667, 99.985, 99.97166666666666, 99.94833333333332, 99.97833333333334, 99.97166666666666, 99.97666666666667, 99.98333333333333]

# %%
acc_list_tanh = [93.36, 94.25, 92.03, 93.57, 93.57, 92.54, 93.5, 94.08, 94.25, 93.82000000000001]
acc_list_tanh_train = [99.99, 99.99166666666667, 99.995, 99.995, 99.99166666666667, 99.97500000000001, 99.98, 99.965, 99.99833333333333, 99.995]
acc_list_sig = [91.63, 92.67, 92.78, 92.81, 92.42, 92.77, 91.43, 91.42, 92.36999999999999, 92.51]
acc_list_sig_train = [99.97166666666666, 99.97333333333333, 99.96166666666667, 99.985, 99.97166666666666, 99.94833333333332, 99.97833333333334, 99.97166666666666, 99.97666666666667, 99.98333333333333]

# %%
plt.clf()

# %%
plt.plot([i+1 for i in range(10)], acc_list_tanh_train, marker='o', color='green', label='tanh training accuracy', linestyle='dashed')
plt.plot([i+1 for i in range(10)], acc_list_sig_train, marker='*', color='orange', label='sigmoid training accuracy', linestyle='dashed')
plt.plot([i+1 for i in range(10)], acc_list_3_train, marker='x', color='purple', label='ReLU training accuracy', linestyle='dashed')
plt.xlabel('Training epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Training epochs (2 hidden layers MLP with different activation functions)')
plt.legend()
plt.show()

# %%
plt.clf()

# %%
a = 0.0001
import math
acc_list_L2_best = []
acc_list_L2_train_best = []
alpha_list_log10 = [] # list of log10(alpha)
acc_alpha = []
best_alpha = None
best = 0
for i in range(9):
    acc_list_L2 = []
    acc_list_L2_train = []
    alpha = a * math.pow(10.0, i)
    clf_L2 = MLPClassifier(hidden_layer_sizes=(128, 2), alpha=alpha, max_iter=400) # default act_func is ReLU
    for epoch in range(10):
        clf_L2.fit(X_train, y_train)
        acc_list_L2.append(clf_L2.score(X_test, y_test)*100.0)
        acc_list_L2_train.append(clf_L2.score(X_train, y_train)*100.0)
    alpha_list_log10.append(math.log10(clf_L2.alpha))
    best_this_iter = np.max(acc_list_L2)
    acc_alpha.append(best_this_iter)
    if best < best_this_iter:
        best = best_this_iter
        acc_list_L2_best = acc_list_L2
        acc_list_L2_train_best = acc_list_L2_train
        best_alpha = clf_L2.alpha
print(acc_list_L2_best)
print(acc_list_L2_train_best)
print(acc_alpha)
print(alpha_list_log10)
print(best_alpha)
print(best)

# %%
plt.plot(alpha_list_log10, acc_alpha, marker='.', color='black')
plt.xlabel('L2 Regularization strength: log10(alpha) ')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. L2 Regularization strength (2 hidden layers MLP)')
plt.legend()
plt.show()

# %%
plt.clf()

# %%
plt.plot([i+1 for i in range(10)], acc_list_L2_best, marker='o', color='blue', label='testing')
plt.plot([i+1 for i in range(10)], acc_list_L2_train_best, marker='*', color='red', label='training', linestyle='dashed')
plt.xlabel('Training epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Training epochs (2 hidden layers MLP with L2 regularization)')
plt.legend()
plt.show()

# %%
plt.clf()

# %%
X_train, X_test = X_train*255.0, X_test*255.0 # undo normalized image

# %%
clf = MLPClassifier(hidden_layer_sizes=(128, 2), alpha=0, max_iter=400) # No L2 regularization
acc_list_unnorm = []
acc_list_unnorm_train = []
for epoch in range(10):
    clf.fit(X_train, y_train)
    acc_list_unnorm.append(clf.score(X_test, y_test)*100.0)
    acc_list_unnorm_train.append(clf.score(X_train, y_train)*100.0)
plt.plot([i+1 for i in range(10)], acc_list_unnorm, marker='o', color='cyan', label='unnormalized images(testing)')
plt.plot([i+1 for i in range(10)], acc_list_unnorm_train, marker='.', color='lime', label='unnormalized images(training)')
plt.plot([i+1 for i in range(10)], acc_list_3, marker='o', color='cyan', label='normalized images(testing)', linestyle='dashed')
plt.plot([i+1 for i in range(10)], acc_list_3_train, marker='.', color='lime', label='normalized images(training)', linestyle='dashed')
plt.legend()
plt.show()
print(acc_list_unnorm)
print(acc_list_unnorm_train)
print(f'The highest score of this model(2 hidden layers & unnormalized) is: {np.max(acc_list_unnorm)}%, No. {np.argmax(acc_list_unnorm)+1} epoch')
print(f'The highest score of this model(2 hidden layers & normalized) is: {np.max(acc_list_3)}%, No. {np.argmax(acc_list_3)+1} epoch')
# Out:
# [11.35, 11.35, 11.35, 93.87, 11.35, 11.35, 11.35, 11.35, 11.35, 11.35]
# [11.236666666666666, 11.236666666666666, 11.236666666666666, 98.425, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666]
# The highest score of this model(2 hidden layers & unnormalized) is: 93.87%, No. 4 epoch
# The highest score of this model(2 hidden layers & normalized) is: 93.91000000000001%, No. 9 epoch

# %%
acc_list_unnorm = [11.35, 11.35, 11.35, 93.87, 11.35, 11.35, 11.35, 11.35, 11.35, 11.35]
acc_list_unnorm_train = [11.236666666666666, 11.236666666666666, 11.236666666666666, 98.425, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666]

# %%
X_train_mean_sub_norm = (X_train - np.mean(X_train))/np.std(X_train) # dif methods of norm
X_test_mean_sub_norm = (X_test - np.mean(X_test))/np.std(X_test)

# %%
clf = MLPClassifier(hidden_layer_sizes=(128, 2), alpha=0, max_iter=400) # No L2 regularization
acc_list_norm = []
acc_list_norm_train = []
for epoch in range(10):
    clf.fit(X_train, y_train)
    acc_list_norm.append(clf.score(X_test, y_test)*100.0)
    acc_list_norm_train.append(clf.score(X_train, y_train)*100.0)
plt.plot([i+1 for i in range(10)], acc_list_norm, marker='o', color='brown', label='normalized images subtracted by mean(testing)')
plt.plot([i+1 for i in range(10)], acc_list_norm_train, marker='.', color='yellow', label='normalized images subtracted by mean(training)')
plt.plot([i+1 for i in range(10)], acc_list_3, marker='o', color='brown', label='normalized images divided by 255(testing)', linestyle='dashed')
plt.plot([i+1 for i in range(10)], acc_list_3_train, marker='.', color='yellow', label='normalized images divided by 255(training)', linestyle='dashed')
plt.legend()
plt.show()
print(acc_list_norm)
print(acc_list_norm_train)
print(f'The highest score of this model(2 hidden layers & mean subtraction) is: {np.max(acc_list_norm)}%, No. {np.argmax(acc_list_norm)+1} epoch')
print(f'The highest score of this model(2 hidden layers & divided by 255) is: {np.max(acc_list_3)}%, No. {np.argmax(acc_list_3)+1} epoch')
# Out:
# [11.35, 11.35, 11.35, 11.35, 11.35, 11.35, 11.35, 11.35, 11.35, 11.35]
# [11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666, 11.236666666666666]
# The highest score of this model(2 hidden layers & mean subtraction) is: 11.35%, No. 1 epoch
# The highest score of this model(2 hidden layers & divided by 255) is: 93.91000000000001%, No. 9 epoch

# %%
plt.clf()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train, X_test = X_train/255.0, X_test/255.0 # normalize again

# %%
import time
test = KNeighborsClassifier(n_neighbors=5, weights='distance')
t0 = time.time()
test.fit(X_train, y_train)
print(test.score(X_train, y_train), test.score(X_test, y_test))
t1 = time.time()
print(t1-t0)
# Out:
# 1.0 0.9691
# 6722.303515911102

# %%
k = 1
acc_list_KNN = []
acc_list_KNN_train = []
for i in [1, 10, 20]:
    K = k * i
    KNN = KNeighborsClassifier(n_neighbors=K)
    KNN.fit(X_train, y_train)
    acc_list_KNN.append(KNN.score(X_test, y_test)*100.0)
    acc_list_KNN_train.append(KNN.score(X_train, y_train)*100.0)

print(f'the highest accuracy of KNN Classifier is: {np.max(acc_list_KNN)}%')
print(acc_list_KNN)
print(acc_list_KNN_train)

# %%
plt.clf()

# %%
acc_list_width_best = []
acc_list_width_train_best = []
acc_width = []
acc_width_train = []
best_acc = 0
best_width = 0
for i in range(1, 6):
    acc_list_width = []
    acc_list_width_train = []
    clf_width = MLPClassifier(hidden_layer_sizes=(100*i, 1), alpha=0.1, max_iter=300)
    for epoch in range(20):
        clf_width.fit(X_train, y_train)
        acc_list_width.append(clf_width.score(X_test, y_test)*100.0)
        acc_list_width_train.append(clf_width.score(X_train, y_train)*100.0)
    best_this = np.max(acc_list_width)
    best_train = acc_list_width_train[np.argmax(acc_list_width)]
    acc_width.append(best_this)
    acc_width_train.append(best_train)
    if best_acc < best_this:
        best_acc = best_this
        acc_list_width_best = acc_list_width
        acc_list_width_train_best = acc_list_width_train
        best_width = clf_width.hidden_layer_sizes[0]
print(best_acc)
print(best_width)
print(acc_list_width_best)
print(acc_list_width_train_best)
print(acc_width)
print(acc_width_train)

# %%
plt.plot([i*100 for i in range(1, 6)], acc_width, marker='.', color='black', label='testing accuracy')
plt.plot([i*100 for i in range(1, 6)], acc_width_train, marker='.', color='black', label='training accuracy', linestyle='dashed')
plt.xlabel('Width of hidden layers (Units)')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Width of hidden layers (1 hidden layers MLP)')
plt.legend()
plt.show()

# %%
plt.clf()

# %%
plt.plot([i for i in range(1, 21)], acc_list_width_best, marker='.', color='lime', label='testing accuracy')
plt.plot([i for i in range(1, 21)], acc_list_width_train_best, marker='.', color='purple', label='training accuracy', linestyle='dashed')
plt.xlabel('Training epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Training epochs (2 hidden layers MLP)')
plt.legend()
plt.show()

# %%
plt.clf()

# %%
clf_test = MLPClassifier(hidden_layer_sizes=(100*2, 2), alpha=0.1, max_iter=300)
print(clf_test.hidden_layer_sizes[0])
# Out:
# 200
